# %%
import matplotlib.pyplot as plt
import numpy as np

import torchvision.transforms as T

import _frameload

# %%
images_train, labels_train, images_test, labels_test = _frameload.main('train/', processes=6)

# %%
transform = T.Compose([
    T.functional.autocontrast,
    T.RandomCrop(384),
    T.ToPILImage(),
])

def showRandom(images, labels, n_subplots=4):
    fig, axes = plt.subplots(1, n_subplots, figsize=(n_subplots * 4, 4))
    idximg = np.random.randint(0, len(images), n_subplots)
    for i, ax in enumerate(axes):
        ax.imshow(transform(images[idximg[i]]))
        ax.set_title('Anime' if labels[idximg[i]] == 1. else 'Photo')
    
    plt.tight_layout()
    plt.show()

# %%
for i in range(4):
    showRandom(images_train, labels_train)

# %%
for i in range(4):
    showRandom(images_test, labels_test)

# %% [markdown]
# Clearly I need some way of masking out things that are just bad exaples of either *photo* or *anime*.  All these credit sequences are basically impossible to tell without contex that is unknowable to the network.
